# %%
from pathlib import Path
import pandas as pd 
import numpy as np
import pingouin as pg
from dowhy import CausalModel
import statsmodels.api as sm
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from scipy import stats
from xgboost import XGBRegressor

import warnings
warnings.filterwarnings('ignore')

import modules
# Nuisance Function Hyperparameters
u_lr = 0.03
u_md = 4
u_ne = 800
l_lr = 0.03
l_md = 4
l_ne = 800
s_lr = 0.03
s_md = 4
s_ne = 800

pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Data preprocessing (Training) - 2024 Data

# %%
mode = 'Train' # 'Train' or 'Test/Congestion' or 'Test/Non_Congest'
    
trn_rts_df = modules.data_prep(mode)

dly_df = trn_rts_df.groupby(['date_of_trip', 'sunday_date', 'month_of_trip', 'day_of_week', 'time_of_day']).agg({'uber_vol' : 'sum', 'lyft_vol' : 'sum'
            , 'uber_wait' : 'mean', 'lyft_wait' : 'mean', 'uber_fare' : 'mean', 'lyft_fare' : 'mean', 'uber_pay' : 'mean', 'lyft_pay' : 'mean'}).reset_index()

dly_df['lyft_share'] = dly_df['lyft_vol'] / (dly_df['uber_vol'] + dly_df['lyft_vol'])

dly_df.columns = ['date_of_trip', 'sunday_date', 'month_of_trip', 'day_of_week', 'time_of_day', 'uber_vol', 'lyft_vol', 'uber_wait_model', 'lyft_wait_model'
                  , 'uber_fare_model', 'lyft_fare_model', 'uber_pay_model', 'lyft_pay_model', 'lyft_share_model']

print(len(dly_df))
dly_df.head()
# Out:
# 420
#   date_of_trip sunday_date month_of_trip  day_of_week  time_of_day  uber_vol  \
# 0   2024-01-01  2023-12-30       2024-01            0            2      4736
# 1   2024-01-01  2023-12-30       2024-01            0            4     13170
# 2   2024-01-02  2023-12-30       2024-01            1            2     15109
# 3   2024-01-02  2023-12-30       2024-01            1            4     16331
# 4   2024-01-03  2023-12-30       2024-01            2            2     17348
#
#    lyft_vol  uber_wait_model  lyft_wait_model  uber_fare_model  \
# 0      3080         5.341869         2.738636         8.712470
# 1      7159         4.781294         2.760020         8.159645
# 2      7920         3.947051         2.687275         8.582401
# 3      8098         3.047398         2.284587         8.833018
# 4      9456         3.445451         2.560074         8.960961
#
#    lyft_fare_model  uber_pay_model  lyft_pay_model  lyft_share_model
# ...

# %% [markdown]
# ### Nuisance Function Models

# %%
dly_df, ufare_report, ufare_model = modules.xgb_predictor(
    df=dly_df,
    objective='reg:squarederror',
    predictor_cols=["uber_wait_model", "lyft_wait_model"],
    target_col="uber_fare_model",
    new_col="uber_fare_model_pred",
    learning_rate=u_lr,
    max_depth=u_md,
    n_estimators=u_ne,
)

dly_df, lfare_report, lfare_model = modules.xgb_predictor(
    df=dly_df,
    objective='reg:squarederror',
    predictor_cols=["uber_wait_model", "lyft_wait_model"],
    target_col="lyft_fare_model",
    new_col="lyft_fare_model_pred",
    learning_rate=l_lr,
    max_depth=l_md,
    n_estimators=l_ne,
)

dly_df, lshare_report, lshare_model = modules.xgb_predictor(
    df=dly_df,    
    objective='reg:squarederror',
    predictor_cols=["uber_wait_model", "lyft_wait_model"],
    target_col="lyft_share_model",
    new_col="lyft_share_model_pred",
    learning_rate=s_lr,
    max_depth=s_md,
    n_estimators=s_ne,
)

dly_df['uber_fare_model_error'] = dly_df['uber_fare_model'] - dly_df['uber_fare_model_pred']
dly_df['lyft_fare_model_error'] = dly_df['lyft_fare_model'] - dly_df['lyft_fare_model_pred']
dly_df['lyft_share_model_error'] = dly_df['lyft_share_model'] - dly_df['lyft_share_model_pred']

dly_df.head()
# Out:
#   date_of_trip sunday_date month_of_trip  day_of_week  time_of_day  uber_vol  \
# 0   2024-01-01  2023-12-30       2024-01            0            2      4736
# 1   2024-01-01  2023-12-30       2024-01            0            4     13170
# 2   2024-01-02  2023-12-30       2024-01            1            2     15109
# 3   2024-01-02  2023-12-30       2024-01            1            4     16331
# 4   2024-01-03  2023-12-30       2024-01            2            2     17348
#
#    lyft_vol  uber_wait_model  lyft_wait_model  uber_fare_model  \
# 0      3080         5.341869         2.738636         8.712470
# 1      7159         4.781294         2.760020         8.159645
# 2      7920         3.947051         2.687275         8.582401
# 3      8098         3.047398         2.284587         8.833018
# 4      9456         3.445451         2.560074         8.960961
#
#    lyft_fare_model  uber_pay_model  lyft_pay_model  lyft_share_model  \
# ...

# %%
nuis_results = pd.concat([ufare_report, lfare_report, lshare_report], axis=0)
nuis_results = nuis_results.reset_index(drop=True)
nuis_results.head()
# Out:
#              Target         Objective    RMSE      R2  \
# 0   uber_fare_model  reg:squarederror  0.4254  0.9313
# 1   lyft_fare_model  reg:squarederror  0.3730  0.9103
# 2  lyft_share_model  reg:squarederror  0.0099  0.8330
#
#    feat_imp_uber_wait_model  feat_imp_lyft_wait_model
# 0                    0.6879                    0.3121
# 1                    0.6401                    0.3599
# 2                    0.5052                    0.4948

# %% [markdown]
# ### Orthogonal Regression Model

# %%
results = modules.fit_linear_regression(
    df=dly_df,
    predictor_cols=['uber_fare_model_error', 'lyft_fare_model_error'],
    target_col='lyft_share_model_error',
    intercept=False
)

print(results.summary())
# Out:
#                                    OLS Regression Results
# ...
# Dep. Variable:     lyft_share_model_error   R-squared (uncentered):                   0.570
# Model:                                OLS   Adj. R-squared (uncentered):              0.568
# Method:                     Least Squares   F-statistic:                              277.5
# Date:                    Mon, 09 Mar 2026   Prob (F-statistic):                    2.09e-77
# Time:                            03:25:19   Log-Likelihood:                          1518.1
# No. Observations:                     420   AIC:                                     -3032.
# Df Residuals:                         418   BIC:                                     -3024.
# Df Model:                               2
# Covariance Type:                nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Data preprocessing (2025 data)

# %%
mode = 'Test/Congestion' # 'Train' or 'Test/Congestion' or 'Test/Non_Congest'

cng_rts_df = modules.data_prep(mode)

mode = 'Test/Non_Congest' # 'Train' or 'Test/Congestion' or 'Test/Non_Congest'

ncg_rts_df = modules.data_prep(mode)

ncg_rts_df = ncg_rts_df.rename(columns={'uber_vol': 'uber_vol_no_congest', 'lyft_vol': 'lyft_vol_no_congest', 'tot_vol' : 'tot_vol_no_congest', 'uber_fare': 'uber_fare_no_congest', 'lyft_fare': 'lyft_fare_no_congest', 'uber_wait': 'uber_wait_no_congest', 'lyft_wait': 'lyft_wait_no_congest', 'lyft_share': 'lyft_share_no_congest'})
cng_rts_df = cng_rts_df.rename(columns={'uber_vol': 'uber_vol_congestion', 'lyft_vol': 'lyft_vol_congestion', 'tot_vol' : 'tot_vol_congestion', 'uber_fare': 'uber_fare_congestion', 'lyft_fare': 'lyft_fare_congestion', 'uber_wait': 'uber_wait_congestion', 'lyft_wait': 'lyft_wait_congestion', 'lyft_share': 'lyft_share_congestion', 'uber_cong_fee_per_mile' : 'uber_congestion_fee', 'lyft_cong_fee_per_mile' : 'lyft_congestion_fee'})

ncg_df = ncg_rts_df.groupby(['date_of_trip', 'sunday_date', 'month_of_trip', 'time_of_day']).agg({'uber_vol_no_congest': 'sum', 'lyft_vol_no_congest': 'sum'
        , 'tot_vol_no_congest': 'sum', 'uber_fare_no_congest': 'mean', 'lyft_fare_no_congest': 'mean', 'uber_wait_no_congest': 'mean', 'lyft_wait_no_congest': 'mean'}).reset_index()

print(len(ncg_df))

ncg_df['lyft_share_no_congest'] = ncg_df['lyft_vol_no_congest'] / ncg_df['tot_vol_no_congest']

cng_df = cng_rts_df.groupby(['date_of_trip', 'sunday_date', 'month_of_trip', 'time_of_day']).agg({'uber_vol_congestion': 'sum', 'lyft_vol_congestion': 'sum'
        , 'tot_vol_congestion': 'sum', 'uber_fare_congestion': 'mean', 'lyft_fare_congestion': 'mean', 'uber_wait_congestion': 'mean'
        , 'lyft_wait_congestion': 'mean', 'uber_congestion_fee': 'mean', 'lyft_congestion_fee': 'mean'}).reset_index()

print(len(cng_df))

cng_df['lyft_share_congestion'] = cng_df['lyft_vol_congestion'] / cng_df['tot_vol_congestion']

res_df = pd.merge(ncg_df, cng_df, on=['date_of_trip', 'sunday_date', 'month_of_trip', 'time_of_day'], how='inner')

res_df['date_of_trip'] = pd.to_datetime(res_df['date_of_trip'])

res_df['uber_wait'] = ((res_df['uber_wait_no_congest'] * res_df['uber_vol_no_congest']) + (res_df['uber_wait_congestion'] * res_df['uber_vol_congestion']))/(res_df['uber_vol_no_congest'] + res_df['uber_vol_congestion'])
res_df['lyft_wait'] = ((res_df['lyft_wait_no_congest'] * res_df['lyft_vol_no_congest']) + (res_df['lyft_wait_congestion'] * res_df['lyft_vol_congestion']))/(res_df['lyft_vol_no_congest'] + res_df['lyft_vol_congestion'])
res_df['uber_fare'] = ((res_df['uber_fare_no_congest'] * res_df['uber_vol_no_congest']) + (res_df['uber_fare_congestion'] * res_df['uber_vol_congestion']))/(res_df['uber_vol_no_congest'] + res_df['uber_vol_congestion'])
res_df['lyft_fare'] = ((res_df['lyft_fare_no_congest'] * res_df['lyft_vol_no_congest']) + (res_df['lyft_fare_congestion'] * res_df['lyft_vol_congestion']))/(res_df['lyft_vol_no_congest'] + res_df['lyft_vol_congestion'])
res_df['lyft_share_congestion_pred'] = res_df['lyft_share_no_congest'] + (results.params['uber_fare_model_error'] * res_df['uber_congestion_fee']) + (results.params['lyft_fare_model_error'] * res_df['lyft_congestion_fee'])

res_df['lyft_share_error'] = res_df['lyft_share_congestion_pred'] - res_df['lyft_share_congestion']

print(len(res_df))
res_df.head()
# Out:
# 418
# 414
# 414
#   date_of_trip sunday_date month_of_trip  time_of_day  uber_vol_no_congest  \
# 0   2025-01-06  2025-01-04       2025-01            2                20332
# 1   2025-01-06  2025-01-04       2025-01            4                18340
# 2   2025-01-07  2025-01-04       2025-01            2                22568
# 3   2025-01-07  2025-01-04       2025-01            4                24978
# 4   2025-01-08  2025-01-04       2025-01            2                24187
#
#    lyft_vol_no_congest  tot_vol_no_congest  uber_fare_no_congest  \
# 0                10221               30553              9.791192
# 1                 6898               25238              8.949829
# 2                10025               32593             10.087748
# 3                10158               35136              9.340472
# 4                10918               35105              9.909036
#
#    lyft_fare_no_congest  uber_wait_no_congest  lyft_wait_no_congest  \
# ...

# %%
date_col = 'month_of_trip'
error_col = 'lyft_share_error'
nocong_col = 'lyft_share_no_congest'
real_col = 'lyft_share_congestion'
pred_col = 'lyft_share_congestion_pred'

df = res_df.loc[res_df['time_of_day'] == 2].groupby(date_col).agg({
    'lyft_share_error': 'mean',
    'lyft_share_no_congest': 'mean',
    'lyft_share_congestion': 'mean',
    'lyft_share_congestion_pred': 'mean',
    'uber_wait' : ['mean', 'std'],
    'lyft_wait' : ['mean', 'std'],
    'uber_fare': ['mean', 'std'],
    'lyft_fare': ['mean', 'std']
    }).reset_index()

df.columns = [date_col, error_col, nocong_col, real_col, pred_col, 'uber_wait', 'uber_wait_std', 'lyft_wait', 'lyft_wait_std', 'uber_fare', 'uber_fare_std', 'lyft_fare', 'lyft_fare_std']

fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(14, 8), sharex=True,
                                gridspec_kw={'height_ratios': [1, 1, 1]})

x = np.arange(len(df))
width = 0.35

# Line graph
ax1.plot(x, df[nocong_col], color='black', label='Actual (No Congestion Fee)', linestyle = 'solid', marker='o', markersize=3)
ax1.plot(x, df[real_col], color='green', label='Actual (Congestion Fee)', linestyle = 'solid', marker='o', markersize=3)
ax1.plot(x, df[pred_col], color='red', label='Predicted (Congestion Fee)', linestyle = 'dashed', marker='o', markersize=3)
ax1.set_ylabel('Lyft Share')
ax1.set_ylim(top=0.5)
ax1.set_ylim(bottom=0)
ax1.legend()
ax1.set_title('Lyft Share: Actual vs Forecast (Mornings Mon thru Thurs)')

ax1.grid(True, alpha=0.3)

# Bar graph: bars span from mean-std to mean+std (bottom at mean-std, height = 2*std)
uber_bottom = df['uber_wait'] - df['uber_wait_std']
uber_height = 2 * df['uber_wait_std']
lyft_bottom = df['lyft_wait'] - df['lyft_wait_std']
lyft_height = 2 * df['lyft_wait_std']

ax2.bar(x - width/2, uber_height, width, bottom=uber_bottom,
        color='black', alpha=0.7, label='Uber Wait (mean ± std)')
ax2.bar(x + width/2, lyft_height, width, bottom=lyft_bottom,
        color='pink', edgecolor='hotpink', alpha=0.8, label='Lyft Wait (mean ± std)')

# Mark the mean with a horizontal line on each bar
for i in range(len(df)):
    ax2.hlines(df['uber_wait'].iloc[i], x[i] - width, x[i], color='white', linewidth=1.5)
    ax2.hlines(df['lyft_wait'].iloc[i], x[i], x[i] + width, color='hotpink', linewidth=1.5)

ax2.set_xticks(x)
ax2.set_xticklabels(df[date_col], rotation=45, ha='right')
ax2.set_ylabel('Wait Time (min)')
ax2.set_ylim(bottom=0)
ax2.legend()
ax2.set_title('Wait Time (Mornings Mon thru Thurs)')
ax2.grid(True, alpha=0.3, axis='y')

uber_bottom = df['uber_fare'] - df['uber_fare_std']
uber_height = 2 * df['uber_fare_std']
lyft_bottom = df['lyft_fare'] - df['lyft_fare_std']
lyft_height = 2 * df['lyft_fare_std']

ax3.bar(x - width/2, uber_height, width, bottom=uber_bottom,
        color='black', alpha=0.7, label='Uber Fare (mean ± std)')
ax3.bar(x + width/2, lyft_height, width, bottom=lyft_bottom,
        color='pink', edgecolor='hotpink', alpha=0.8, label='Lyft Fare (mean ± std)')

# Mark the mean with a horizontal line on each bar
for i in range(len(df)):
    ax3.hlines(df['uber_fare'].iloc[i], x[i] - width, x[i], color='white', linewidth=1.5)
    ax3.hlines(df['lyft_fare'].iloc[i], x[i], x[i] + width, color='hotpink', linewidth=1.5)

ax3.set_xticks(x)
ax3.set_xticklabels(df[date_col], ha='right')
ax3.set_ylabel('Fare per mile (USD)')
ax3.set_ylim(bottom=0)
ax3.legend()
ax3.set_title('Fare per mile (Mornings Mon thru Thurs)')
ax3.grid(True, alpha=0.3, axis='y')

ax1.set_xlim(ax2.get_xlim())
ax3.set_xlim(ax2.get_xlim())
plt.tight_layout()
plt.xlabel('Month')
plt.show()
